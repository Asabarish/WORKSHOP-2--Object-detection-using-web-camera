# %% [markdown]
# # Workshop 2 - Object detection using web camera
# ## Name : Sabarish A
# ## Register number : 212225230232

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\acer\anaconda3\lib\site-packages (8.4.117)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (3.20.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (3.10.5)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.7.0 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (5.0.0.93)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: torch>=1.8.0 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (2.13.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (0.28.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (1.43.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.1.6 in c:\users\acer\anaconda3\lib\site-packages (from ultralytics) (2.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.43.2 in c:\users\acer\anaconda3\lib\site-packages (from polars>=0.20.0->ultralytics) (1.43.2)
# Requirement already satisfied: six>=1.5 in c:\users\acer\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\acer\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\acer\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\acer\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\acer\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\acer\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\acer\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\acer\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from IPython.display import clear_output
# Out:
# Creating new Ultralytics Settings v0.0.7 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\acer\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load a more accurate YOLO model
model = YOLO("yolov8m.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8m.pt to 'yolov8m.pt': 100% ━━━━━━━━━━━━ 49.7MB 1.7MB/s 28.6s8.6s<0.0s7sss

# %%
# Open webcam
cap = cv2.VideoCapture(0)

# %%
# Check if camera opened
if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    while True:
        ret, frame = cap.read()

        if not ret:
            print("Failed to capture frame.")
            break

        # Perform object detection
        results = model(
            frame,
            conf=0.60,       
            verbose=False
        )

        # Draw bounding boxes and labels
        annotated_frame = results[0].plot()

        # Convert BGR to RGB for Matplotlib
        annotated_frame = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)

        # Display in Jupyter
        clear_output(wait=True)
        plt.figure(figsize=(10, 8))
        plt.imshow(annotated_frame)
        plt.title("Real-Time Object Detection")
        plt.axis("off")
        plt.show()

# Release webcam
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 13
#      10     break
#      12 # Perform object detection
# ---> 13 results = model(
#      14     frame,
#      15     conf=0.60,
#      16     verbose=False
#      17 )
#      19 # Draw bounding boxes and labels
#      20 annotated_frame = results[0].plot()
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\model.py:166, in Model.__call__(self, source, stream, **kwargs)
#     138 def __call__(
#     139     self,
#     140     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     141     stream: bool = False,
#     142     **kwargs: Any,
#     143 ) -> Iterator[Results | torch.Tensor] | list[Results] | list[torch.Tensor]:
#     144     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     145
#     146     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    164         ...     print(f"Detected {len(r)} objects in image")
#     165     """
# --> 166     return self.predict(source, stream, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\model.py:520, in Model.predict(self, source, stream, predictor, **kwargs)
#     518 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     519     self.predictor.set_prompts(prompts)
# --> 520 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:241, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     239     return self.stream_inference(source, model, *args, **kwargs)
#     240 else:
# --> 241     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:349, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     347 # Inference
#     348 with profilers[1]:
# --> 349     preds = self.inference(im, *args, **kwargs)
#     350     if self.args.embed:
#     351         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:198, in BasePredictor.inference(self, im, *args, **kwargs)
#     187 if self.args.visualize and getattr(self.model, "base_model", True) and not skip:
#     188     return class_activation_map(
#     189         self.model,
#     190         im,
#    (...)    196         **kwargs,
#     197     )
# --> 198 return self.model(im, *args, augment=self.args.augment, embed=self.args.embed, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\autobackend.py:285, in AutoBackend.forward(self, im, augment, embed, **kwargs)
#     282 if self.format == "pt":
#     283     forward_kwargs = {"augment": augment, "embed": embed, **kwargs}
# --> 285 y = self.backend.forward(im, **forward_kwargs)
#     287 if isinstance(y, (list, tuple)):
#     288     if len(self.names) == 999 and (self.task == "segment" or len(y) == 2):  # segments and names not defined
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\backends\pytorch.py:93, in PyTorchBackend.forward(self, im, augment, embed, **kwargs)
#      91 if not self.base_model:  # a foreign nn.Module defines no `augment`/`embed` contract to honor
#      92     return self.model(im, **kwargs)
# ---> 93 return self.model(im, augment=augment, embed=embed, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:157, in BaseModel.forward(self, x, *args, **kwargs)
#     155 if isinstance(x, dict):  # for cases of training and validating while training.
#     156     return self.loss(x, *args, **kwargs)
# --> 157 return self.predict(x, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:173, in BaseModel.predict(self, x, profile, augment, embed)
#     171 if augment:
#     172     return self._predict_augment(x)
# --> 173 return self._predict_once(x, profile, embed)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:194, in BaseModel._predict_once(self, x, profile, embed)
#     192 if profile:
#     193     self._profile_one_layer(m, x, dt)
# --> 194 x = m(x)  # run
#     195 y.append(x if m.i in self.save else None)  # save output
#     196 if m.i in embed:
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\anaconda3\Lib\site-packages\ultralytics\nn\modules\conv.py:89, in Conv.forward_fuse(self, x)
#      80 def forward_fuse(self, x):
#      81     """Apply convolution and activation without batch normalization.
#      82
#      83     Args:
#    (...)     87         (torch.Tensor): Output tensor.
#      88     """
# ---> 89     return self.act(self.conv(x))
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\conv.py:565, in Conv2d.forward(self, input)
#     564 def forward(self, input: Tensor) -> Tensor:
# --> 565     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\conv.py:560, in Conv2d._conv_forward(self, input, weight, bias)
#     547 if self.padding_mode != "zeros":
#     548     return F.conv2d(
#     549         F.pad(
#     550             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    557         self.groups,
#     558     )
# --> 560 return F.conv2d(
#     561     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     562 )
#
# KeyboardInterrupt:
